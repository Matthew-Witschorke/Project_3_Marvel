# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data1 = "charcters_stats.csv"

df1 = pd.read_csv(data1)
df1.head(20)
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0             3-D Man      good            50        31     43          32
# 1              A-Bomb      good            38       100     17          80
# 2          Abe Sapien      good            88        14     35          42
# 3            Abin Sur      good            50        90     53          64
# 4         Abomination       bad            63        80     53          90
# 5             Abraxas       bad            88       100     83          99
# 6         Adam Monroe      good            63        10     12         100
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 9           Agent Bob      good            10         8     13           5
# 10         Agent Zero      good            75        28     38          80
# ...

# %%
data2 = "marvel_characters_info.csv"

df2 = pd.read_csv(data2)
df2.head(20)
# Out:
#     ID               Name Alignment  Gender EyeColor               Race  \
# 0    0             A-Bomb      good    Male   yellow              Human
# 1    1         Abe Sapien      good    Male     blue      Icthyo Sapien
# 2    2           Abin Sur      good    Male     blue            Ungaran
# 3    3        Abomination       bad    Male    green  Human / Radiation
# 4    4            Abraxas       bad    Male     blue      Cosmic Entity
# 5    5      Absorbing Man       bad    Male     blue              Human
# 6    6        Adam Monroe      good    Male     blue                  -
# 7    7       Adam Strange      good    Male     blue              Human
# 8    8           Agent 13      good  Female     blue                  -
# 9    9          Agent Bob      good    Male    brown              Human
# 10  10         Agent Zero      good    Male        -                  -
# 11  11         Air-Walker       bad    Male     blue                  -
# ...

# %%
df2.drop(['ID', 'Alignment'], axis=1, inplace=True)

# %%
df2.reset_index
df2
# Out:
#                 Name  Gender EyeColor               Race         HairColor  \
# 0             A-Bomb    Male   yellow              Human           No Hair
# 1         Abe Sapien    Male     blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male     blue            Ungaran           No Hair
# 3        Abomination    Male    green  Human / Radiation           No Hair
# 4            Abraxas    Male     blue      Cosmic Entity             Black
# ..               ...     ...      ...                ...               ...
# 729  Yellowjacket II  Female     blue              Human  Strawberry Blond
# 730             Ymir    Male    white        Frost Giant           No Hair
# 731             Yoda    Male    brown     Yoda's species             White
# 732          Zatanna  Female     blue              Human             Black
# 733             Zoom    Male      red                  -             Brown
#
#              Publisher SkinColor  Height  Weight
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       734 non-null    object
#  1   Gender     734 non-null    object
#  2   EyeColor   734 non-null    object
#  3   Race       734 non-null    object
#  4   HairColor  734 non-null    object
#  5   Publisher  719 non-null    object
#  6   SkinColor  734 non-null    object
#  7   Height     734 non-null    float64
#  8   Weight     732 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 51.7+ KB

# %%
data3 = "superheroes_power_matrix.csv"

df3 = pd.read_csv(data3)
df3.head(20)
# Out:
#                 Name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# 5            Abraxas    False                False               False
# 6      Absorbing Man    False                False               False
# 7        Adam Monroe    False                 True               False
# 8       Adam Strange    False                False               False
# 9          Agent Bob    False                False               False
# 10        Agent Zero    False                False               False
# 11        Air-Walker    False                False               False
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, Name to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
df3.describe()
# Out:
#            Name Agility Accelerated Healing Lantern Power Ring  \
# count       667     667                 667                667
# unique      667       2                   2                  2
# top     3-D Man   False               False              False
# freq          1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight  ... Web Creation Reality Warping Odin Force  \
# count                667    667  ...          667             667        667
# unique                 2      2  ...            2               2          2
# top                False  False  ...        False           False      False
# ...

# %%
total_data = df1.merge(df2, on='Name')
total_data.head(20)
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0              A-Bomb      good            38       100     17          80
# 1          Abe Sapien      good            88        14     35          42
# 2            Abin Sur      good            50        90     53          64
# 3         Abomination       bad            63        80     53          90
# 4             Abraxas       bad            88       100     83          99
# 5         Adam Monroe      good            63        10     12         100
# 6        Adam Strange      good             1         1      1           1
# 7           Agent Bob      good            10         8     13           5
# 8          Agent Zero      good            75        28     38          80
# 9          Air-Walker       bad            50        85    100          85
# 10         Alan Scott      good            63        80     23          90
# ...

# %%
inner_join_df= pd.merge(total_data, df3, on='Name', how='inner')
inner_join_df.head()
# Out:
#           Name Alignment  Intelligence_x  Strength  Speed  Durability_x  \
# 0       A-Bomb      good              38       100     17            80
# 1   Abe Sapien      good              88        14     35            42
# 2     Abin Sur      good              50        90     53            64
# 3  Abomination       bad              63        80     53            90
# 4      Abraxas       bad              88       100     83            99
#
#    Power  Combat  Total Gender  ... Web Creation Reality Warping Odin Force  \
# 0     17      64    316   Male  ...        False           False      False
# 1     35      85    299   Male  ...        False           False      False
# 2     84      65    406   Male  ...        False           False      False
# 3     55      95    436   Male  ...        False           False      False
# 4    100      56    526   Male  ...        False           False      False
#
#   Symbiote Costume Speed Force  Phoenix Force  Molecular Dissipation  \
# ...

# %%
inner_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534 entries, 0 to 533
# Columns: 184 entries, Name to Omniscient
# dtypes: bool(167), float64(2), int64(7), object(8)
# memory usage: 162.2+ KB

# %%
inner_join_df.describe
# Out:
# <bound method NDFrame.describe of                 Name Alignment  Intelligence_x  Strength  Speed  Durability_x  \
# 0             A-Bomb      good              38       100     17            80
# 1         Abe Sapien      good              88        14     35            42
# 2           Abin Sur      good              50        90     53            64
# 3        Abomination       bad              63        80     53            90
# 4            Abraxas       bad              88       100     83            99
# ..               ...       ...             ...       ...    ...           ...
# 529     Yellowjacket      good              88        10     12            28
# 530  Yellowjacket II      good              50        10     35            28
# 531             Ymir      good              50       100     27           100
# 532          Zatanna      good              75        10     23            28
# 533             Zoom       bad              50        10    100            28
#
# ...

# %%
inner_join_df.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence_x', 'Strength', 'Speed',
#        'Durability_x', 'Power', 'Combat', 'Total', 'Gender',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=184)

# %%
#total_data = total_data.loc[:,~total_data.columns.duplicated()]
#total_data.head()

# %%
columns = inner_join_df.columns
for c in columns:
    print (c)
# Out:
# Name
# Alignment
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability_y
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence_y
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# ...

# %%
inner_join_df.drop(['Intelligence_y', 'Durability_y'], axis=1, inplace=True)

# %%
inner_join_df.head()
# Out:
#           Name Alignment  Intelligence_x  Strength  Speed  Durability_x  \
# 0       A-Bomb      good              38       100     17            80
# 1   Abe Sapien      good              88        14     35            42
# 2     Abin Sur      good              50        90     53            64
# 3  Abomination       bad              63        80     53            90
# 4      Abraxas       bad              88       100     83            99
#
#    Power  Combat  Total Gender  ... Web Creation Reality Warping Odin Force  \
# 0     17      64    316   Male  ...        False           False      False
# 1     35      85    299   Male  ...        False           False      False
# 2     84      65    406   Male  ...        False           False      False
# 3     55      95    436   Male  ...        False           False      False
# 4    100      56    526   Male  ...        False           False      False
#
#   Symbiote Costume Speed Force  Phoenix Force  Molecular Dissipation  \
# ...

# %%
inner_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534 entries, 0 to 533
# Columns: 182 entries, Name to Omniscient
# dtypes: bool(165), float64(2), int64(7), object(8)
# memory usage: 161.1+ KB

# %%
final_df = inner_join_df

# %%
final_df.to_csv('final_df2.csv')

# %%
final_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Alignment</th>\n      <th>Intelligence_x</th>\n      <th>Strength</th>\n      <th>Speed</th>\n      <th>Durability_x</th>\n      <th>Power</th>\n      <th>Combat</th>\n      <th>Total</th>\n      <th>Gender</th>\n      <th>EyeColor</th>\n      <th>Race</th>\n      <th>HairColor</th>\n      <th>Publisher</th>\n      <th>SkinColor</th>\n      <th>Height</th>\n      <th>Weight</th>\n      <th>Agility</th>\n      <th>Accelerated Healing</th>\n      <th>Lantern Power Ring</th>\n      <th>Dimensional Awareness</th>\n      <th>Cold Resistance</th>\n      <th>Stealth</th>\n      <th>Energy Absorption</th>\n      <th>Flight</th>\n      <th>Danger Sense</th>\n      <th>Underwater breathing</th>\n      <th>Marksmanship</th>\n      <th>Weapons Master</th>\n      <th>Power Augmentation</th>\n      <th>Animal Attributes</th>\n      <th>Longevity</th>\n      <th>Sup
# ...

# %%
total_data.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0       A-Bomb      good            38       100     17          80     17
# 1   Abe Sapien      good            88        14     35          42     35
# 2     Abin Sur      good            50        90     53          64     84
# 3  Abomination       bad            63        80     53          90     55
# 4      Abraxas       bad            88       100     83          99    100
#
#    Combat  Total Gender EyeColor               Race HairColor  \
# 0      64    316   Male   yellow              Human   No Hair
# 1      85    299   Male     blue      Icthyo Sapien   No Hair
# 2      65    406   Male     blue            Ungaran   No Hair
# 3      95    436   Male    green  Human / Radiation   No Hair
# 4      56    526   Male     blue      Cosmic Entity     Black
#
#            Publisher SkinColor  Height  Weight
# 0      Marvel Comics         -   203.0   441.0
# ...

# %%
total_data.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Alignment</th>\n      <th>Intelligence</th>\n      <th>Strength</th>\n      <th>Speed</th>\n      <th>Durability</th>\n      <th>Power</th>\n      <th>Combat</th>\n      <th>Total</th>\n      <th>Gender</th>\n      <th>EyeColor</th>\n      <th>Race</th>\n      <th>HairColor</th>\n      <th>Publisher</th>\n      <th>SkinColor</th>\n      <th>Height</th>\n      <th>Weight</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>A-Bomb</td>\n      <td>good</td>\n      <td>38</td>\n      <td>100</td>\n      <td>17</td>\n      <td>80</td>\n      <td>17</td>\n      <td>64</td>\n      <td>316</td>\n      <td>Male</td>\n      <td>yellow</td>\n      <td>Human</td>\n      <td>No Hair</td>\n      <td>Marvel Comics</td>\n      <td>-</td>\n      <td>203.0</td>\n      <td>441.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Abe Sapien</
# ...
